# %%
#Executing given code
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df =pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df1 =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# 1. Get the Metadata from the above files.

# %%
#Metadata of 1tst data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
#Metadata of berlin weather data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# 2. Get the row names from the above files

# %%
#Row details of Life Exp Data set
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
#Row details of Weather Data set
df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# 3. Change the column name from any of the above file.

# %%
#before changing column name
df.head(1)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
#
#    High  Comments
# 0   NaN       NaN

# %%
#After Changing
df=df.rename(columns={'Indicator':'Indicator_Id'})
df.head(3)
# Out:
#                         Indicator_Id PUBLISH STATES  Year WHO region  \
# 0   Life expectancy at birth (years)      Published  1990     Europe
# 1   Life expectancy at birth (years)      Published  2000     Europe
# 2  Life expectancy at age 60 (years)      Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
# 4. Change the column name from any of the above file and store the changes made permanently.

# %%
#After Changing column name permanently
df.rename(columns={'Indicator':'Indicator_Id'},inplace=True)
df.head(3)
# Out:
#                         Indicator_Id PUBLISH STATES  Year WHO region  \
# 0   Life expectancy at birth (years)      Published  1990     Europe
# 1   Life expectancy at birth (years)      Published  2000     Europe
# 2  Life expectancy at age 60 (years)      Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
# 5. Change the names of multiple columns.

# %%
#changing name of multiple columns permenently
df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace=True)
df.head(3)
# Out:
#                         Indicator_Id Publication Status  Year WHO Region  \
# 0   Life expectancy at birth (years)          Published  1990     Europe
# 1   Life expectancy at birth (years)          Published  2000     Europe
# 2  Life expectancy at age 60 (years)          Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
# 6. Arrange values of a particular column in ascending order.

# %%
#Sorting based on Year
df.sort_values('Year')
# Out:
#                                          Indicator_Id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# 7. Arrange multiple column values in ascending order.

# %%
#Sorting based on 'Indicator_Id','Year','Country','WHO Region','Publication Status'
df.loc[:,['Indicator_Id','Year','Country','WHO Region','Publication Status']].sort_values(by=['Indicator_Id','Year','Country','WHO Region','Publication Status'])
# Out:
#                                          Indicator_Id  Year  \
# 2798  Healthy life expectancy (HALE) at birth (years)  2000
# 3363  Healthy life expectancy (HALE) at birth (years)  2000
# 4456  Healthy life expectancy (HALE) at birth (years)  2000
# 2598  Healthy life expectancy (HALE) at birth (years)  2000
# 3690  Healthy life expectancy (HALE) at birth (years)  2000
# 3691  Healthy life expectancy (HALE) at birth (years)  2000
# 3408  Healthy life expectancy (HALE) at birth (years)  2000
# 3734  Healthy life expectancy (HALE) at birth (years)  2000
# 4114  Healthy life expectancy (HALE) at birth (years)  2000
# 3367  Healthy life expectancy (HALE) at birth (years)  2000
# 3368  Healthy life expectancy (HALE) at birth (years)  2000
# 3369  Healthy life expectancy (HALE) at birth (years)  2000
# 2246  Healthy life expectancy (HALE) at birth (years)  2000
# 2247  Healthy life expectancy (HALE) at birth (years)  2000
# 3364  Healthy life expectancy (HALE) at birth (years)  2000
# ...

# %% [markdown]
# 8. Make countryas the first column of the dataframe.

# %%
#Rearranging column names
df[['Country','Indicator_Id','Publication Status','Year','WHO Region','World Bank income group','Sex','Display Value','Numeric','Low','High','Comments']]
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %% [markdown]
# 9. Get the column array using a variable

# %%
#Define Column Name variable
column_name='WHO Region'
#Describe the array
df[column_name].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %% [markdown]
# 10. Get the subset rows 11, 24, 37

# %%
#Passing the list of index to iloc function
df.iloc[[11,24,37]]
# Out:
#                          Indicator_Id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
#Droping the given indexes
df.drop(df.index[[5,12,23,56]])
# Out:
#                                          Indicator_Id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1                    Life expectancy at birth (years)          Published
# 2                   Life expectancy at age 60 (years)          Published
# 3                   Life expectancy at age 60 (years)          Published
# 4                    Life expectancy at birth (years)          Published
# 6                   Life expectancy at age 60 (years)          Published
# 7                   Life expectancy at age 60 (years)          Published
# 8                    Life expectancy at birth (years)          Published
# 9                    Life expectancy at birth (years)          Published
# 10                   Life expectancy at birth (years)          Published
# 11                   Life expectancy at birth (years)          Published
# 13                   Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# Load datasets from CSV

# %%
#Loading Dataset
users=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
#Descripbe the dataframes
sessions.head()
transactions.head()
products.head()
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %% [markdown]
# 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
#correcting transcation data
transactions.rename(columns={'UserID':'Quantit'},inplace=True)
transactions.rename(columns={'Quantity':'UserID','Quantit':'Quantity'},inplace=True)
transactions.head()
# Out:
#    TransactionID TransactionDate  Quantity  ProductID  UserID
# 0              1      2010-08-21       7.0          2       1
# 1              2      2011-05-26       3.0          4       1
# 2              3      2011-06-16       3.0          3       1
# 3              4      2012-08-26       1.0          2       3
# 4              5      2013-06-06       2.0          4       1

# %%
#left joining transactions by user id
transactions.merge(users,on='UserID',how='left')
# Out:
#    TransactionID TransactionDate  Quantity  ProductID  UserID      User  \
# 0              1      2010-08-21       7.0          2       1   Charles
# 1              2      2011-05-26       3.0          4       1   Charles
# 2              3      2011-06-16       3.0          3       1   Charles
# 3              4      2012-08-26       1.0          2       3  Caroline
# 4              5      2013-06-06       2.0          4       1   Charles
# 5              6      2013-12-23       2.0          5       6       NaN
# 6              7      2013-12-30       3.0          4       1   Charles
# 7              8      2014-04-24       NaN          2       3  Caroline
# 8              9      2015-04-24       7.0          4       3  Caroline
# 9             10      2016-05-08       3.0          4       4   Brielle
#
#    Gender  Registered   Cancelled
# 0    male  2012-12-21         NaN
# 1    male  2012-12-21         NaN
# 2    male  2012-12-21         NaN
# 3  female  2012-10-23  2016-06-07
# ...

# %% [markdown]
# 13. Which transactions have a UserID not in users?

# %%
#Do an anti join to find 
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  Quantity  ProductID  UserID
# 5              6      2013-12-23       2.0          5       6

# %% [markdown]
# 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
#Do an Inner Join
transactions.merge(users,on='UserID',how='inner')
# Out:
#    TransactionID TransactionDate  Quantity  ProductID  UserID      User  \
# 0              1      2010-08-21       7.0          2       1   Charles
# 1              2      2011-05-26       3.0          4       1   Charles
# 2              3      2011-06-16       3.0          3       1   Charles
# 3              5      2013-06-06       2.0          4       1   Charles
# 4              7      2013-12-30       3.0          4       1   Charles
# 5              4      2012-08-26       1.0          2       3  Caroline
# 6              8      2014-04-24       NaN          2       3  Caroline
# 7              9      2015-04-24       7.0          4       3  Caroline
# 8             10      2016-05-08       3.0          4       4   Brielle
#
#    Gender  Registered   Cancelled
# 0    male  2012-12-21         NaN
# 1    male  2012-12-21         NaN
# 2    male  2012-12-21         NaN
# 3    male  2012-12-21         NaN
# 4    male  2012-12-21         NaN
# 5  female  2012-10-23  2016-06-07
# ...

# %% [markdown]
# 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
#Do outter join 
transactions.merge(users,on='UserID',how='outer')
# Out:
#     TransactionID TransactionDate  Quantity  ProductID  UserID      User  \
# 0             1.0      2010-08-21       7.0        2.0       1   Charles
# 1             2.0      2011-05-26       3.0        4.0       1   Charles
# 2             3.0      2011-06-16       3.0        3.0       1   Charles
# 3             5.0      2013-06-06       2.0        4.0       1   Charles
# 4             7.0      2013-12-30       3.0        4.0       1   Charles
# 5             4.0      2012-08-26       1.0        2.0       3  Caroline
# 6             8.0      2014-04-24       NaN        2.0       3  Caroline
# 7             9.0      2015-04-24       7.0        4.0       3  Caroline
# 8             6.0      2013-12-23       2.0        5.0       6       NaN
# 9            10.0      2016-05-08       3.0        4.0       4   Brielle
# 10            NaN             NaN       NaN        NaN       2     Pedro
# 11            NaN             NaN       NaN        NaN       5  Benjamin
#
# ...

# %% [markdown]
# 16. Determine which sessions occurred on the same day each user registered

# %%
#Need to join on two columns 
users.merge(sessions,how='inner',left_on=['UserID', 'Registered'], right_on=['UserID', 'SessionDate'])
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %% [markdown]
# 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
#Find No of unique elements
n_users=users.shape[0]
n_product=products.shape[0]
#Create separate dataframes
df1 = pd.DataFrame({'ID': np.repeat(1, n_users), 'UserID': users.UserID})
df2 = pd.DataFrame({'ID': np.repeat(1, n_product), 'ProductID': products.ProductID})
#Merge the above dataframes
df3=pd.merge(df1, df2,on='ID')[['UserID', 'ProductID']]
df3
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# 18. Determine how much quantity of each product was purchased by each user

# %%
#Merge two dataframes and calculate te sum of suantities 
pd.merge(df3, transactions, how='left', on=['UserID', 'ProductID']).groupby(['UserID', 'ProductID']).apply(
    lambda x: pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index()
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       7.0
# 2        1          3       3.0
# 3        1          4       8.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       0.0
# 9        2          5       0.0
# 10       3          1       0.0
# 11       3          2       1.0
# 12       3          3       0.0
# 13       3          4       7.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       3.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %% [markdown]
# 19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
#do a self join
transactions.merge(transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  Quantity_x  ProductID_x  UserID  \
# 0                 1        2010-08-21         7.0            2       1
# 1                 1        2010-08-21         7.0            2       1
# 2                 1        2010-08-21         7.0            2       1
# 3                 1        2010-08-21         7.0            2       1
# 4                 1        2010-08-21         7.0            2       1
# 5                 2        2011-05-26         3.0            4       1
# 6                 2        2011-05-26         3.0            4       1
# 7                 2        2011-05-26         3.0            4       1
# 8                 2        2011-05-26         3.0            4       1
# 9                 2        2011-05-26         3.0            4       1
# 10                3        2011-06-16         3.0            3       1
# 11                3        2011-06-16         3.0            3       1
# ...

# %% [markdown]
# 20. Join each user to his/her first occuring transaction in the transactions table

# %%
#Group transactions
tr1=transactions.groupby('UserID').first()
#Merger transactionswith users
df4=users.merge(tr1, how='left', on='UserID')
df4
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            1.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            NaN
# 2       3  Caroline  female  2012-10-23  2016-06-07            4.0
# 3       4   Brielle  female  2013-07-17         NaN           10.0
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  Quantity  ProductID
# 0      2010-08-21       7.0        2.0
# 1             NaN       NaN        NaN
# 2      2012-08-26       1.0        2.0
# 3      2016-05-08       3.0        4.0
# 4             NaN       NaN        NaN

# %% [markdown]
# 21. Test to see if we can drop columns

# %%
#drop product id column
transactions.head()
transactions.drop(['ProductID'],axis=1)
# Out:
#    TransactionID TransactionDate  Quantity  UserID
# 0              1      2010-08-21       7.0       1
# 1              2      2011-05-26       3.0       1
# 2              3      2011-06-16       3.0       1
# 3              4      2012-08-26       1.0       3
# 4              5      2013-06-06       2.0       1
# 5              6      2013-12-23       2.0       6
# 6              7      2013-12-30       3.0       1
# 7              8      2014-04-24       NaN       3
# 8              9      2015-04-24       7.0       3
# 9             10      2016-05-08       3.0       4

# %%
#drop column from df4
df4.drop('User',axis=1)
# Out:
#    UserID  Gender  Registered   Cancelled  TransactionID TransactionDate  \
# 0       1    male  2012-12-21         NaN            1.0      2010-08-21
# 1       2    male  2010-08-01  2010-08-08            NaN             NaN
# 2       3  female  2012-10-23  2016-06-07            4.0      2012-08-26
# 3       4  female  2013-07-17         NaN           10.0      2016-05-08
# 4       5    male  2010-11-25         NaN            NaN             NaN
#
#    Quantity  ProductID
# 0       7.0        2.0
# 1       NaN        NaN
# 2       1.0        2.0
# 3       3.0        4.0
# 4       NaN        NaN

# %%
sessions.head()
transactions.head()
products.head()
#users.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66
